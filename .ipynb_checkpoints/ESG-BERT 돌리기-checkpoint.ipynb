# %% [markdown]
# # 모듈 임포트

# %%
import pandas as pd
import numpy as np
import transformers
import os 
import re
from tqdm import tqdm
from transformers import pipeline

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("nbroad/ESG-BERT")

model = AutoModelForSequenceClassification.from_pretrained("nbroad/ESG-BERT")

# %% [markdown]
# # 뉴스 데이터 로드

# %%
nytimes_df = pd.read_csv('/Users/parkjunhyeong/Desktop/Composed_Data_ver0.6.csv', index_col = 0)

# %%
nytimes_df
# Out:
#                                                     URL Publish Date  \
# 0     https://www.nytimes.com/2019/01/01/business/me...   2019-01-01
# 1     https://www.nytimes.com/2019/01/02/business/ju...   2019-01-02
# 2     https://www.nytimes.com/2019/01/02/business/te...   2019-01-02
# 3     https://www.nytimes.com/2019/01/03/business/de...   2019-01-03
# 4     https://www.nytimes.com/2019/01/03/business/de...   2019-01-03
# ...                                                 ...          ...
# 4561  https://www.nytimes.com/2022/10/18/technology/...   2022-10-18
# 4562  https://www.nytimes.com/2022/10/20/technology/...   2022-10-20
# 4563  https://www.nytimes.com/2022/10/25/technology/...   2022-10-25
# 4564  https://www.nytimes.com/2022/10/27/technology/...   2022-10-27
# 4565  https://www.nytimes.com/2022/10/27/technology/...   2022-10-27
#
#                                                   Title  \
# 0     Netflix Blocks Show in Saudi Arabia Critical o...
# 1     Julie Sweet of Accenture Could See Her Future....
# 2     Tesla Reports Record Output, but Cuts Prices, ...
# 3     Bristol-Myers to Acquire Celgene in Deal Worth...
# 4     Was Apple’s Warning a Surprise? Not to Its Sup...
# ...                                                 ...
# 4561  Amazon Labor Union Loses Election at Warehouse...
# 4562  Texas Sues Google for Collecting Biometric Dat...
# 4563  Microsoft Reports Slowest Revenue Growth in Fi...
# 4564  Apple’s iPhone Powers Growth, but Signs Point ...
# 4565  Amazon Returns to Growth but Signals Slowness ...
#
#                                               Main Text    Ticker  \
# 0     Netflix has blocked an episode of its show “Pa...  ['NFLX']
# 1     Why did you go to law school?\n \n I decided t...   ['ACN']
# 2     Tesla shares ended trading nearly 7 percent lo...  ['TSLA']
# 3     Bristol-Myers Squibb said on Thursday that it ...   ['BMY']
# 4     Apple’s stock fell 10 percent on Thursday, its...  ['AAPL']
# ...                                                 ...       ...
# 4561  Mr. Smalls said the election “wasn’t free and ...  ['AMZN']
# 4562  José Castañeda, a Google spokesman, said in a ...  ['GOOG']
# 4563  In the most recent quarter, softness in the gl...  ['MSFT']
# 4564  When Apple released the 16th version of its iP...  ['AAPL']
# 4565  The results come amid a rocky patch for tech g...  ['AMZN']
#
#                     Description              News Type Sentiment  \
# 0               ['Netflix Inc']                    ESG  Negative
# 1     ['Accenture Plc Class A']                Non-ESG  Positive
# 2                 ['Tesla Inc']  Financial Performance  Negative
# 3      ['Bristol Myers Squibb']  Financial Performance   Neutral
# 4                 ['Apple Inc']  Financial Performance  Negative
# ...                         ...                    ...       ...
# 4561        ['Amazon.Com Inc.']                    ESG  Positive
# 4562   ['Alphabet Inc Class C']                    ESG  Negative
# 4563         ['Microsoft Corp']  Financial Performance  Positive
# 4564              ['Apple Inc']  Financial Performance  Positive
# 4565        ['Amazon.Com Inc.']  Financial Performance  Negative
#
#       Date Comparison  Investor Reaction  Positive Consumer Perception  \
# 0                True           0.064605                     -0.025613
# 1                True          -0.001291                     -0.025522
# 2                True          -0.010247                     -0.004269
# 3                True          -0.059849                           NaN
# 4                True          -0.027306                      0.000000
# ...               ...                ...                           ...
# 4561             True           0.010129                      0.000000
# 4562             True          -0.040082                      0.032693
# 4563             True          -0.036752                     -0.036672
# 4564             True          -0.003742                     -0.036672
# 4565             True          -0.091115                           NaN
#
#       Negative Consumer Perception            GICS Sectors  esg_score  \
# 0                         0.019053  Communication Services        NaN
# 1                         0.007074  Information Technology        NaN
# 2                        -0.009292  Consumer Discretionary        NaN
# 3                              NaN             Health Care   0.921570
# 4                         0.000000  Information Technology   0.785918
# ...                            ...                     ...        ...
# 4561                      0.000000  Consumer Discretionary   0.539786
# 4562                     -0.005359  Communication Services   0.711950
# 4563                      0.025153  Information Technology   0.928991
# 4564                      0.025153  Information Technology   0.785918
# 4565                           NaN  Consumer Discretionary   0.539786
#
#       Firm Age  Twitter Followers  Total Asset    ROA
# 0           23           21667744       33.976   6.07
# 1           31             551168       29.790  20.99
# 2           17           19694123       34.309  -1.94
# 3          133             157472      129.940   3.83
# 4           44            9115548      338.516  19.42
# ...        ...                ...          ...    ...
# 4561        29            5401566      462.675  -1.28
# 4562        25           28908576      365.264  16.71
# 4563        48           12790258      364.840  22.95
# 4564        47            9115548      352.755  33.76
# 4565        29            5401566      462.675  -1.28
#
# [4566 rows x 18 columns]

# %%
nytimes_df['Main Text'].iloc[0]
# Out:
# 'Netflix has blocked an episode of its show “Patriot Act With Hasan Minhaj” from streaming in Saudi Arabia after the Saudi government complained that the episode — which is critical of the crown prince, Mohammed bin Salman — violated its cybercrime laws.\n \n In the episode, first shown in October, Mr. Minhaj critiques the United States’ longstanding relationship with Saudi Arabia after the murder of the dissident Saudi journalist Jamal Khashoggi.\n \n “Now would be a good time to reassess our relationship with Saudi Arabia,” Mr. Minhaj said, “and I mean that as a Muslim and an American.”\n \n After receiving a takedown request last month from the Saudi government’s Communications and Information Technology Commission, Netflix removed the episode from viewing in Saudi Arabia last week. The news was first reported by The Financial Times.'

# %% [markdown]
# # 데이터 전처리 및 자르기

# %%
def clean_text(sent):
    sent_clean = re.sub('\n\n', ' ', sent)
    sent_clean = re.sub('[^a-zA-Z]', ' ', sent)
    return sent_clean

# %%
nytimes_df['clean_text'] = nytimes_df['Main Text'].apply(lambda x : clean_text(str(x)))

# %%
nytimes_df['clean_text'].iloc[0]
# Out:
# 'Netflix has blocked an episode of its show  Patriot Act With Hasan Minhaj  from streaming in Saudi Arabia after the Saudi government complained that the episode   which is critical of the crown prince  Mohammed bin Salman   violated its cybercrime laws     In the episode  first shown in October  Mr  Minhaj critiques the United States  longstanding relationship with Saudi Arabia after the murder of the dissident Saudi journalist Jamal Khashoggi      Now would be a good time to reassess our relationship with Saudi Arabia   Mr  Minhaj said   and I mean that as a Muslim and an American      After receiving a takedown request last month from the Saudi government s Communications and Information Technology Commission  Netflix removed the episode from viewing in Saudi Arabia last week  The news was first reported by The Financial Times '

# %%
nytimes_df['clean_text'] = nytimes_df['clean_text'].str.split(' ')

# %%
remove_set = ['']
for i in range(len(nytimes_df)):
    nytimes_df['clean_text'][i] = [l for l in nytimes_df['clean_text'][i] if l not in remove_set]
# Out:
# /var/folders/z6/nn0fl27x39547ybzc5y11s8m0000gn/T/ipykernel_6805/662184775.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nytimes_df['clean_text'][i] = [l for l in nytimes_df['clean_text'][i] if l not in remove_set]

# %%
nytimes_df['clean_text'][0]
# Out:
# ['Netflix',
#  'has',
#  'blocked',
#  'an',
#  'episode',
#  'of',
#  'its',
#  'show',
#  'Patriot',
#  'Act',
#  'With',
#  'Hasan',
#  'Minhaj',
#  'from',
#  'streaming',
#  'in',
#  'Saudi',
#  'Arabia',
#  'after',
#  'the',
#  'Saudi',
#  'government',
#  'complained',
#  'that',
#  'the',
#  'episode',
#  'which',
#  'is',
#  'critical',
#  'of',
#  'the',
#  'crown',
#  'prince',
#  'Mohammed',
#  'bin',
#  'Salman',
#  'violated',
#  'its',
#  'cybercrime',
#  'laws',
#  'In',
#  'the',
#  'episode',
#  'first',
#  'shown',
#  'in',
#  'October',
#  'Mr',
#  'Minhaj',
#  'critiques',
#  'the',
#  'United',
#  'States',
#  'longstanding',
#  'relationship',
#  'with',
#  'Saudi',
#  'Arabia',
#  'after',
#  'the',
#  'murder',
#  'of',
#  'the',
#  'dissident',
#  'Saudi',
#  'journalist',
#  'Jamal',
#  'Khashoggi',
#  'Now',
#  'would',
#  'be',
#  'a',
#  'good',
#  'time',
#  'to',
#  'reassess',
#  'our',
#  'relationship',
#  'with',
#  'Saudi',
#  'Arabia',
#  'Mr',
#  'Minhaj',
#  'said',
#  'and',
#  'I',
#  'mean',
#  'that',
#  'as',
#  'a',
#  'Muslim',
#  'and',
#  'an',
#  'American',
#  'After',
#  'receiving',
#  'a',
#  'takedown',
#  'request',
#  'last',
#  'month',
#  'from',
#  'the',
#  'Saudi',
#  'government',
#  's',
#  'Communications',
#  'and',
#  'Information',
#  'Technology',
#  'Commission',
#  'Netflix',
#  'removed',
#  'the',
#  'episode',
#  'from',
#  'viewing',
#  'in',
#  'Saudi',
#  'Arabia',
#  'last',
#  'week',
#  'The',
#  'news',
#  'was',
#  'first',
#  'reported',
#  'by',
#  'The',
#  'Financial',
#  'Times']

# %%
nytimes_df['truncated_text'] = nytimes_df['clean_text'].apply(lambda x : x[:400])

# %%
nytimes_df['clean_text'] = nytimes_df['clean_text'].str.join(' ')
nytimes_df['truncated_text'] = nytimes_df['truncated_text'].str.join(' ')

# %%
nytimes_df
# Out:
#                                                     URL Publish Date  \
# 0     https://www.nytimes.com/2019/01/01/business/me...   2019-01-01
# 1     https://www.nytimes.com/2019/01/02/business/ju...   2019-01-02
# 2     https://www.nytimes.com/2019/01/02/business/te...   2019-01-02
# 3     https://www.nytimes.com/2019/01/03/business/de...   2019-01-03
# 4     https://www.nytimes.com/2019/01/03/business/de...   2019-01-03
# ...                                                 ...          ...
# 4561  https://www.nytimes.com/2022/10/18/technology/...   2022-10-18
# 4562  https://www.nytimes.com/2022/10/20/technology/...   2022-10-20
# 4563  https://www.nytimes.com/2022/10/25/technology/...   2022-10-25
# 4564  https://www.nytimes.com/2022/10/27/technology/...   2022-10-27
# 4565  https://www.nytimes.com/2022/10/27/technology/...   2022-10-27
#
#                                                   Title  \
# 0     Netflix Blocks Show in Saudi Arabia Critical o...
# 1     Julie Sweet of Accenture Could See Her Future....
# 2     Tesla Reports Record Output, but Cuts Prices, ...
# 3     Bristol-Myers to Acquire Celgene in Deal Worth...
# 4     Was Apple’s Warning a Surprise? Not to Its Sup...
# ...                                                 ...
# 4561  Amazon Labor Union Loses Election at Warehouse...
# 4562  Texas Sues Google for Collecting Biometric Dat...
# 4563  Microsoft Reports Slowest Revenue Growth in Fi...
# 4564  Apple’s iPhone Powers Growth, but Signs Point ...
# 4565  Amazon Returns to Growth but Signals Slowness ...
#
#                                               Main Text    Ticker  \
# 0     Netflix has blocked an episode of its show “Pa...  ['NFLX']
# 1     Why did you go to law school?\n \n I decided t...   ['ACN']
# 2     Tesla shares ended trading nearly 7 percent lo...  ['TSLA']
# 3     Bristol-Myers Squibb said on Thursday that it ...   ['BMY']
# 4     Apple’s stock fell 10 percent on Thursday, its...  ['AAPL']
# ...                                                 ...       ...
# 4561  Mr. Smalls said the election “wasn’t free and ...  ['AMZN']
# 4562  José Castañeda, a Google spokesman, said in a ...  ['GOOG']
# 4563  In the most recent quarter, softness in the gl...  ['MSFT']
# 4564  When Apple released the 16th version of its iP...  ['AAPL']
# 4565  The results come amid a rocky patch for tech g...  ['AMZN']
#
#                     Description              News Type Sentiment  \
# 0               ['Netflix Inc']                    ESG  Negative
# 1     ['Accenture Plc Class A']                Non-ESG  Positive
# 2                 ['Tesla Inc']  Financial Performance  Negative
# 3      ['Bristol Myers Squibb']  Financial Performance   Neutral
# 4                 ['Apple Inc']  Financial Performance  Negative
# ...                         ...                    ...       ...
# 4561        ['Amazon.Com Inc.']                    ESG  Positive
# 4562   ['Alphabet Inc Class C']                    ESG  Negative
# 4563         ['Microsoft Corp']  Financial Performance  Positive
# 4564              ['Apple Inc']  Financial Performance  Positive
# 4565        ['Amazon.Com Inc.']  Financial Performance  Negative
#
#       Date Comparison  Investor Reaction  Positive Consumer Perception  \
# 0                True           0.064605                     -0.025613
# 1                True          -0.001291                     -0.025522
# 2                True          -0.010247                     -0.004269
# 3                True          -0.059849                           NaN
# 4                True          -0.027306                      0.000000
# ...               ...                ...                           ...
# 4561             True           0.010129                      0.000000
# 4562             True          -0.040082                      0.032693
# 4563             True          -0.036752                     -0.036672
# 4564             True          -0.003742                     -0.036672
# 4565             True          -0.091115                           NaN
#
#       Negative Consumer Perception            GICS Sectors  esg_score  \
# 0                         0.019053  Communication Services        NaN
# 1                         0.007074  Information Technology        NaN
# 2                        -0.009292  Consumer Discretionary        NaN
# 3                              NaN             Health Care   0.921570
# 4                         0.000000  Information Technology   0.785918
# ...                            ...                     ...        ...
# 4561                      0.000000  Consumer Discretionary   0.539786
# 4562                     -0.005359  Communication Services   0.711950
# 4563                      0.025153  Information Technology   0.928991
# 4564                      0.025153  Information Technology   0.785918
# 4565                           NaN  Consumer Discretionary   0.539786
#
#       Firm Age  Twitter Followers  Total Asset    ROA  \
# 0           23           21667744       33.976   6.07
# 1           31             551168       29.790  20.99
# 2           17           19694123       34.309  -1.94
# 3          133             157472      129.940   3.83
# 4           44            9115548      338.516  19.42
# ...        ...                ...          ...    ...
# 4561        29            5401566      462.675  -1.28
# 4562        25           28908576      365.264  16.71
# 4563        48           12790258      364.840  22.95
# 4564        47            9115548      352.755  33.76
# 4565        29            5401566      462.675  -1.28
#
#                                              clean_text  \
# 0     Netflix has blocked an episode of its show Pat...
# 1     Why did you go to law school I decided that I ...
# 2     Tesla shares ended trading nearly percent lowe...
# 3     Bristol Myers Squibb said on Thursday that it ...
# 4     Apple s stock fell percent on Thursday its wor...
# ...                                                 ...
# 4561  Mr Smalls said the election wasn t free and fa...
# 4562  Jos Casta eda a Google spokesman said in a sta...
# 4563  In the most recent quarter softness in the glo...
# 4564  When Apple released the th version of its iPho...
# 4565  The results come amid a rocky patch for tech g...
#
#                                          truncated_text
# 0     Netflix has blocked an episode of its show Pat...
# 1     Why did you go to law school I decided that I ...
# 2     Tesla shares ended trading nearly percent lowe...
# 3     Bristol Myers Squibb said on Thursday that it ...
# 4     Apple s stock fell percent on Thursday its wor...
# ...                                                 ...
# 4561  Mr Smalls said the election wasn t free and fa...
# 4562  Jos Casta eda a Google spokesman said in a sta...
# 4563  In the most recent quarter softness in the glo...
# 4564  When Apple released the th version of its iPho...
# 4565  The results come amid a rocky patch for tech g...
#
# [4566 rows x 20 columns]

# %% [markdown]
# # ESG-BERT 돌리기

# %%
esg_bert = pipeline('text-classification', model = model, tokenizer = tokenizer)

def esg_bert_func(sent):
    try:
        return esg_bert(sent, top_k = None)
    except Exception as e:
        print(e)
        print(sent)
        pass

# %%
tqdm.pandas()
nytimes_df['esg_bert_score'] = nytimes_df['truncated_text'].progress_apply(lambda x : esg_bert_func(x))
# Out:
#  18%|███████▎                                | 836/4566 [01:33<08:57,  6.94it/s]

# %%
nytimes_df['esg_bert'] = nytimes_df['esg_bert'].apply(lambda x : x[0]['label'])

# %%
nytimes_df.to_csv('/Users/parkjunhyeong/Desktop/Composed_Data_ver0.3.csv')
